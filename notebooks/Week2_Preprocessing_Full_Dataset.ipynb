# %% [markdown]
# # Week-2: BraTS2020 Data Preprocessing (FULL DATASET - 369 PATIENTS)
#
# ## Overview
# This notebook processes **ALL 369 patients** from the BraTS2020 training dataset for maximum performance.
#
# **Key Features:**
# - ✅ Process all 369 patients automatically
# - ✅ Generate 6,000-10,000 patches total
# - ✅ Tumor-focused sampling (85% tumor patches)
# - ✅ Robust error handling
# - ✅ Progress tracking and checkpointing
#
# **Expected Output:**
# - ~369 patients × ~17-27 patches = **6,273-9,963 patches**
# - Train set: **~5,000-8,000 patches**
# - Val set: **~1,250-2,000 patches**
#
# **Processing Time:**
# - Estimated: **6-10 hours** (depends on your CPU)
# - Recommended: Run overnight
#
# **Storage Required:**
# - ~40-50 GB for preprocessed patches

# %%
# Cell 1: Import Libraries

import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
from pathlib import Path
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import warnings
import time
from datetime import datetime
warnings.filterwarnings('ignore')

# Set random seed
np.random.seed(42)

# Set style
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.1)

print("✓ All libraries imported successfully")
print(f"NumPy version: {np.__version__}")
print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✓ All libraries imported successfully
# NumPy version: 2.3.4
# Start time: 2025-10-30 16:33:39

# %%
# Cell 2: Configuration (FULL DATASET - 369 PATIENTS)

# Paths
BASE_PATH = os.path.join('..', 'BraTS2020_training_data', 'MICCAI_BraTS2020_TrainingData')
OUTPUT_DIR = os.path.join('..', 'processed_data')

# AUTO-DISCOVER ALL PATIENTS
print("="*70)
print("SCANNING FOR PATIENTS...")
print("="*70)

# Find all patient directories
patient_dirs = glob.glob(os.path.join(BASE_PATH, 'BraTS20_Training_*'))
PATIENT_IDS = sorted([os.path.basename(p) for p in patient_dirs])

print(f"Found {len(PATIENT_IDS)} patient directories")
if len(PATIENT_IDS) > 0:
    print(f"First patient: {PATIENT_IDS[0]}")
    print(f"Last patient: {PATIENT_IDS[-1]}")
else:
    print("⚠️  WARNING: No patient directories found!")
    print(f"   Check if BASE_PATH is correct: {BASE_PATH}")

# Preprocessing parameters
TARGET_SHAPE = (128, 128, 128)
PATCH_SIZE = (64, 64, 64)
STRIDE = (32, 32, 32)
TRAIN_VAL_SPLIT = 0.2

# Normalization
PERCENTILE_LOWER = 0.5
PERCENTILE_UPPER = 99.5

# Tumor-focused sampling (BALANCED)
TUMOR_THRESHOLD = 0.0001
BACKGROUND_SAMPLE_RATIO = 0.20  # Keep 20% of background patches for better balance

# Processing options
SAVE_CHECKPOINT_EVERY = 50  # Save progress every 50 patients
MAX_PATIENTS = None  # Set to a number to limit (e.g., 100 for testing), None for all

print("\n" + "="*70)
print("PREPROCESSING CONFIGURATION (FULL DATASET)")
print("="*70)
print(f"Total patients found: {len(PATIENT_IDS)}")
if MAX_PATIENTS:
    print(f"Processing limit: {MAX_PATIENTS} patients (for testing)")
    PATIENT_IDS = PATIENT_IDS[:MAX_PATIENTS]
else:
    print(f"Processing: ALL {len(PATIENT_IDS)} patients")

print(f"\nExpected patches per patient: ~17-27")
print(f"Expected total patches: ~{len(PATIENT_IDS) * 20} (conservative estimate)")
print(f"Expected train patches: ~{int(len(PATIENT_IDS) * 20 * 0.8)}")
print(f"Expected val patches: ~{int(len(PATIENT_IDS) * 20 * 0.2)}")

print(f"\nPatch parameters:")
print(f"  Target shape: {TARGET_SHAPE}")
print(f"  Patch size: {PATCH_SIZE}")
print(f"  Stride: {STRIDE}")

print(f"\n🎯 Tumor sampling:")
print(f"  Tumor threshold: {TUMOR_THRESHOLD}")
print(f"  Background ratio: {BACKGROUND_SAMPLE_RATIO} (20%)")
print(f"  Expected tumor patches: ~85%")

print(f"\n💾 Storage:")
print(f"  Estimated size: ~{len(PATIENT_IDS) * 20 * 5 / 1000:.1f} GB")

print(f"\n⏱️  Processing time:")
print(f"  Estimated: {len(PATIENT_IDS) * 1.5 / 60:.1f} hours")
print(f"  Checkpoint every: {SAVE_CHECKPOINT_EVERY} patients")

print("="*70)

if len(PATIENT_IDS) == 0:
    raise ValueError("No patients found! Check your BASE_PATH.")
# Out:
# ======================================================================
# SCANNING FOR PATIENTS...
# ======================================================================
# Found 369 patient directories
# First patient: BraTS20_Training_001
# Last patient: BraTS20_Training_369
#
# ======================================================================
# PREPROCESSING CONFIGURATION (FULL DATASET)
# ======================================================================
# Total patients found: 369
# Processing: ALL 369 patients
#
# Expected patches per patient: ~17-27
# Expected total patches: ~7380 (conservative estimate)
# Expected train patches: ~5904
# Expected val patches: ~1476
#
# Patch parameters:
#   Target shape: (128, 128, 128)
#   Patch size: (64, 64, 64)
#   Stride: (32, 32, 32)
#
# 🎯 Tumor sampling:
#   Tumor threshold: 0.0001
#   Background ratio: 0.2 (20%)
#   Expected tumor patches: ~85%
#
# 💾 Storage:
#   Estimated size: ~36.9 GB
#
# ⏱️  Processing time:
#   Estimated: 9.2 hours
#   Checkpoint every: 50 patients
# ======================================================================

# %%
# Cell 3: Create Output Directory Structure

def create_directory_structure(base_dir):
    """Create organized folder structure."""
    directories = [
        os.path.join(base_dir, 'train', 'images'),
        os.path.join(base_dir, 'train', 'masks'),
        os.path.join(base_dir, 'val', 'images'),
        os.path.join(base_dir, 'val', 'masks'),
        os.path.join(base_dir, 'metadata'),
        os.path.join(base_dir, 'checkpoints')  # For saving progress
    ]
    
    for directory in directories:
        os.makedirs(directory, exist_ok=True)
    
    return directories

created_dirs = create_directory_structure(OUTPUT_DIR)

print("✓ Directory structure created:")
for directory in created_dirs:
    print(f"  • {directory}")
# Out:
# ✓ Directory structure created:
#   • ..\processed_data\train\images
#   • ..\processed_data\train\masks
#   • ..\processed_data\val\images
#   • ..\processed_data\val\masks
#   • ..\processed_data\metadata
#   • ..\processed_data\checkpoints

# %%
# Cell 4: Load NIfTI Volumes Function

def load_nifti_volumes(patient_path, patient_id):
    """Load all MRI modalities and segmentation mask."""
    modalities = {
        'flair': os.path.join(patient_path, f"{patient_id}_flair.nii"),
        't1': os.path.join(patient_path, f"{patient_id}_t1.nii"),
        't1ce': os.path.join(patient_path, f"{patient_id}_t1ce.nii"),
        't2': os.path.join(patient_path, f"{patient_id}_t2.nii"),
        'seg': os.path.join(patient_path, f"{patient_id}_seg.nii")
    }
    
    # Also try .nii.gz extension
    volumes = {}
    for modality, file_path in modalities.items():
        if os.path.exists(file_path):
            volumes[modality] = nib.load(file_path).get_fdata()
        elif os.path.exists(file_path + '.gz'):
            volumes[modality] = nib.load(file_path + '.gz').get_fdata()
    
    return volumes

print("✓ Load function defined")
# Out:
# ✓ Load function defined

# %%
# Cell 5: Preprocessing Functions

def convert_to_float32(volume):
    return volume.astype(np.float32)

def clip_intensity_percentiles(volume, lower=0.5, upper=99.5):
    if np.max(volume) == 0:
        return volume
    lower_bound = np.percentile(volume[volume > 0], lower)
    upper_bound = np.percentile(volume[volume > 0], upper)
    return np.clip(volume, lower_bound, upper_bound)

def zscore_normalize(volume):
    if np.max(volume) == 0:
        return volume
    mask = volume > 0
    mean = np.mean(volume[mask])
    std = np.std(volume[mask])
    if std > 0:
        volume[mask] = (volume[mask] - mean) / std
    return np.nan_to_num(volume, nan=0.0, posinf=0.0, neginf=0.0)

def center_crop_or_pad(volume, target_shape):
    current_shape = volume.shape
    padded_volume = np.zeros(target_shape, dtype=volume.dtype)
    
    slices = []
    for current, target in zip(current_shape, target_shape):
        if current < target:
            pad_before = (target - current) // 2
            slices.append((pad_before, pad_before + current))
        else:
            crop_before = (current - target) // 2
            slices.append((crop_before, crop_before + target))
    
    if all(c >= t for c, t in zip(current_shape, target_shape)):
        padded_volume = volume[
            slices[0][0]:slices[0][1],
            slices[1][0]:slices[1][1],
            slices[2][0]:slices[2][1]
        ]
    else:
        src_slices = []
        for current, target in zip(current_shape, target_shape):
            if current < target:
                src_slices.append(slice(0, current))
            else:
                crop = (current - target) // 2
                src_slices.append(slice(crop, crop + target))
        padded_volume[
            slices[0][0]:slices[0][1],
            slices[1][0]:slices[1][1],
            slices[2][0]:slices[2][1]
        ] = volume[src_slices[0], src_slices[1], src_slices[2]]
    
    return padded_volume

def preprocess_volume(volume, is_mask=False):
    volume = convert_to_float32(volume)
    if not is_mask:
        volume = clip_intensity_percentiles(volume, PERCENTILE_LOWER, PERCENTILE_UPPER)
        volume = zscore_normalize(volume)
    volume = center_crop_or_pad(volume, TARGET_SHAPE)
    return volume

print("✓ Preprocessing functions defined")
# Out:
# ✓ Preprocessing functions defined

# %%
# Cell 6: Patch Extraction Functions

def extract_patches_3d(volume, patch_size, stride):
    d, h, w = volume.shape
    pd, ph, pw = patch_size
    sd, sh, sw = stride
    
    patches = []
    positions = []
    
    for z in range(0, d - pd + 1, sd):
        for y in range(0, h - ph + 1, sh):
            for x in range(0, w - pw + 1, sw):
                patch = volume[z:z+pd, y:y+ph, x:x+pw]
                patches.append(patch)
                positions.append((z, y, x))
    
    return patches, positions

def calculate_tumor_ratio(mask_patch):
    total_voxels = mask_patch.size
    tumor_voxels = np.count_nonzero(mask_patch)
    return tumor_voxels / total_voxels

def extract_patches_from_volumes(volumes, patch_size, stride, 
                                 tumor_threshold=0.0001, 
                                 background_ratio=0.20):
    modality_list = ['flair', 't1', 't1ce', 't2']
    stacked_volume = np.stack([volumes[mod] for mod in modality_list], axis=0)
    seg_volume = volumes['seg']
    
    _, positions = extract_patches_3d(volumes['flair'], patch_size, stride)
    
    tumor_patches = []
    background_patches = []
    
    for idx, (z, y, x) in enumerate(positions):
        pd, ph, pw = patch_size
        image_patch = stacked_volume[:, z:z+pd, y:y+ph, x:x+pw]
        mask_patch = seg_volume[z:z+pd, y:y+ph, x:x+pw]
        tumor_ratio = calculate_tumor_ratio(mask_patch)
        
        patch_dict = {
            'image': image_patch,
            'mask': mask_patch,
            'position': (z, y, x),
            'tumor_ratio': tumor_ratio
        }
        
        if tumor_ratio >= tumor_threshold:
            tumor_patches.append(patch_dict)
        else:
            background_patches.append(patch_dict)
    
    n_background_keep = int(len(background_patches) * background_ratio)
    if n_background_keep < len(background_patches):
        background_indices = np.random.choice(len(background_patches), 
                                             n_background_keep, 
                                             replace=False)
        background_patches = [background_patches[i] for i in background_indices]
    
    return tumor_patches, background_patches

print("✓ Patch extraction functions defined")
# Out:
# ✓ Patch extraction functions defined

# %%
# Cell 7: Process ALL Patients with Progress Tracking

print("\n" + "="*70)
print("PROCESSING ALL PATIENTS")
print("="*70)
print(f"Total patients to process: {len(PATIENT_IDS)}")
print(f"Estimated time: {len(PATIENT_IDS) * 1.5 / 60:.1f} hours")
print(f"Start time: {datetime.now().strftime('%H:%M:%S')}")
print("\n💡 TIP: This will take several hours. Consider running overnight.")
print("="*70 + "\n")

all_tumor_patches = []
all_background_patches = []
processed_patients = []
failed_patients = []

start_time = time.time()

for patient_idx, patient_id in enumerate(PATIENT_IDS, 1):
    patient_start = time.time()
    
    # Progress header
    if patient_idx % 10 == 1 or patient_idx == len(PATIENT_IDS):
        elapsed = time.time() - start_time
        elapsed_hours = elapsed / 3600
        remaining = (elapsed / patient_idx) * (len(PATIENT_IDS) - patient_idx) if patient_idx > 0 else 0
        remaining_hours = remaining / 3600
        
        print(f"\n{'='*70}")
        print(f"Progress: {patient_idx}/{len(PATIENT_IDS)} ({100*patient_idx/len(PATIENT_IDS):.1f}%)")
        print(f"Elapsed: {elapsed_hours:.2f}h | Remaining: ~{remaining_hours:.2f}h")
        print(f"Current: {patient_id}")
        print(f"{'='*70}")
    
    patient_path = os.path.join(BASE_PATH, patient_id)
    
    if not os.path.exists(patient_path):
        failed_patients.append((patient_id, "Directory not found"))
        print(f"⚠️  [{patient_idx}/{len(PATIENT_IDS)}] {patient_id}: Directory not found")
        continue
    
    try:
        # Load volumes
        raw_volumes = load_nifti_volumes(patient_path, patient_id)
        
        # Check completeness
        required_modalities = ['flair', 't1', 't1ce', 't2', 'seg']
        if not all(mod in raw_volumes for mod in required_modalities):
            failed_patients.append((patient_id, "Missing modalities"))
            print(f"⚠️  [{patient_idx}/{len(PATIENT_IDS)}] {patient_id}: Missing modalities")
            continue
        
        # Preprocess
        preprocessed_volumes = {}
        for modality in ['flair', 't1', 't1ce', 't2']:
            preprocessed_volumes[modality] = preprocess_volume(raw_volumes[modality], is_mask=False)
        preprocessed_volumes['seg'] = preprocess_volume(raw_volumes['seg'], is_mask=True)
        
        # Extract patches
        tumor_patches, background_patches = extract_patches_from_volumes(
            preprocessed_volumes,
            PATCH_SIZE,
            STRIDE,
            tumor_threshold=TUMOR_THRESHOLD,
            background_ratio=BACKGROUND_SAMPLE_RATIO
        )
        
        # Add patient ID
        for patch in tumor_patches:
            patch['patient_id'] = patient_id
        for patch in background_patches:
            patch['patient_id'] = patient_id
        
        all_tumor_patches.extend(tumor_patches)
        all_background_patches.extend(background_patches)
        processed_patients.append(patient_id)
        
        patient_time = time.time() - patient_start
        total_patches = len(tumor_patches) + len(background_patches)
        print(f"✓ [{patient_idx}/{len(PATIENT_IDS)}] {patient_id}: {total_patches} patches ({patient_time:.1f}s)")
        
        # Save checkpoint
        if patient_idx % SAVE_CHECKPOINT_EVERY == 0:
            checkpoint_data = {
                'tumor_patches': all_tumor_patches,
                'background_patches': all_background_patches,
                'processed_patients': processed_patients,
                'failed_patients': failed_patients,
                'progress': patient_idx
            }
            checkpoint_path = os.path.join(OUTPUT_DIR, 'checkpoints', f'checkpoint_{patient_idx}.npy')
            np.save(checkpoint_path, checkpoint_data, allow_pickle=True)
            print(f"💾 Checkpoint saved: {patient_idx} patients processed")
        
    except Exception as e:
        failed_patients.append((patient_id, str(e)))
        print(f"❌ [{patient_idx}/{len(PATIENT_IDS)}] {patient_id}: Error - {str(e)[:50]}")
        continue

# Combine all patches
all_patches = all_tumor_patches + all_background_patches
np.random.shuffle(all_patches)

total_time = time.time() - start_time

print(f"\n{'='*70}")
print("PROCESSING COMPLETE!")
print(f"{'='*70}")
print(f"Total time: {total_time/3600:.2f} hours")
print(f"Successfully processed: {len(processed_patients)}/{len(PATIENT_IDS)} patients")
print(f"Failed: {len(failed_patients)} patients")
print(f"\nTotal patches: {len(all_patches)}")
print(f"Tumor patches: {len(all_tumor_patches)} ({100*len(all_tumor_patches)/len(all_patches):.1f}%)")
print(f"Background patches: {len(all_background_patches)} ({100*len(all_background_patches)/len(all_patches):.1f}%)")
print(f"Average patches per patient: {len(all_patches)//len(processed_patients)}")
print(f"{'='*70}")

if len(failed_patients) > 0:
    print(f"\n⚠️  Failed patients ({len(failed_patients)}):")
    for pid, reason in failed_patients[:10]:  # Show first 10
        print(f"  • {pid}: {reason}")
    if len(failed_patients) > 10:
        print(f"  ... and {len(failed_patients)-10} more")
# Out:
# ======================================================================
# PROCESSING ALL PATIENTS
# ======================================================================
# Total patients to process: 369
# Estimated time: 9.2 hours
# Start time: 16:33:39
#
# 💡 TIP: This will take several hours. Consider running overnight.
# ======================================================================
#
#
# ======================================================================
# Progress: 1/369 (0.3%)
# Elapsed: 0.00h | Remaining: ~0.00h
# Current: BraTS20_Training_001
# ======================================================================
# ✓ [1/369] BraTS20_Training_001: 27 patches (2.0s)
# ✓ [2/369] BraTS20_Training_002: 17 patches (2.1s)
# ✓ [3/369] BraTS20_Training_003: 15 patches (2.1s)
# ✓ [4/369] BraTS20_Training_004: 15 patches (2.1s)
# ✓ [5/369] BraTS20_Training_005: 11 patches (2.2s)
# ✓ [6/369] BraTS20_Training_006: 26 patches (2.2s)
# ✓ [7/369] BraTS20_Training_007: 15 patches (2.4s)
# ✓ [8/369] BraTS20_Training_008: 15 patches (2.5s)
# ✓ [9/369] BraTS20_Training_009: 24 patches (1.9s)
# ✓ [10/369] BraTS20_Training_010: 19 patches (2.1s)
#
# ======================================================================
# Progress: 11/369 (3.0%)
# Elapsed: 0.01h | Remaining: ~0.20h
# Current: BraTS20_Training_011
# ======================================================================
# ✓ [11/369] BraTS20_Training_011: 18 patches (2.4s)
# ✓ [12/369] BraTS20_Training_012: 17 patches (2.3s)
# ✓ [13/369] BraTS20_Training_013: 24 patches (1.8s)
# ✓ [14/369] BraTS20_Training_014: 18 patches (1.8s)
# ✓ [15/369] BraTS20_Training_015: 19 patches (1.9s)
# ✓ [16/369] BraTS20_Training_016: 19 patches (2.0s)
# ✓ [17/369] BraTS20_Training_017: 19 patches (2.4s)
# ✓ [18/369] BraTS20_Training_018: 24 patches (2.4s)
# ✓ [19/369] BraTS20_Training_019: 17 patches (2.3s)
# ✓ [20/369] BraTS20_Training_020: 19 patches (2.4s)
#
# ======================================================================
# Progress: 21/369 (5.7%)
# Elapsed: 0.01h | Remaining: ~0.20h
# Current: BraTS20_Training_021
# ======================================================================
# ✓ [21/369] BraTS20_Training_021: 19 patches (2.3s)
# ✓ [22/369] BraTS20_Training_022: 26 patches (2.4s)
# ✓ [23/369] BraTS20_Training_023: 16 patches (2.3s)
# ✓ [24/369] BraTS20_Training_024: 15 patches (2.4s)
# ✓ [25/369] BraTS20_Training_025: 21 patches (2.4s)
# ✓ [26/369] BraTS20_Training_026: 24 patches (2.4s)
# ✓ [27/369] BraTS20_Training_027: 19 patches (2.4s)
# ✓ [28/369] BraTS20_Training_028: 11 patches (2.5s)
# ✓ [29/369] BraTS20_Training_029: 18 patches (2.4s)
# ✓ [30/369] BraTS20_Training_030: 23 patches (2.4s)
#
# ======================================================================
# Progress: 31/369 (8.4%)
# Elapsed: 0.02h | Remaining: ~0.20h
# Current: BraTS20_Training_031
# ======================================================================
# ✓ [31/369] BraTS20_Training_031: 23 patches (2.2s)
# ✓ [32/369] BraTS20_Training_032: 15 patches (1.9s)
# ✓ [33/369] BraTS20_Training_033: 19 patches (1.8s)
# ✓ [34/369] BraTS20_Training_034: 21 patches (2.0s)
# ✓ [35/369] BraTS20_Training_035: 24 patches (2.4s)
# ✓ [36/369] BraTS20_Training_036: 13 patches (2.3s)
# ✓ [37/369] BraTS20_Training_037: 19 patches (2.5s)
# ✓ [38/369] BraTS20_Training_038: 18 patches (2.4s)
# ✓ [39/369] BraTS20_Training_039: 15 patches (2.4s)
# ✓ [40/369] BraTS20_Training_040: 19 patches (2.5s)
#
# ======================================================================
# Progress: 41/369 (11.1%)
# Elapsed: 0.02h | Remaining: ~0.20h
# Current: BraTS20_Training_041
# ======================================================================
# ✓ [41/369] BraTS20_Training_041: 15 patches (2.5s)
# ✓ [42/369] BraTS20_Training_042: 17 patches (2.3s)
# ✓ [43/369] BraTS20_Training_043: 20 patches (2.3s)
# ✓ [44/369] BraTS20_Training_044: 23 patches (2.5s)
# ✓ [45/369] BraTS20_Training_045: 18 patches (2.4s)
# ✓ [46/369] BraTS20_Training_046: 19 patches (2.5s)
# ✓ [47/369] BraTS20_Training_047: 27 patches (2.5s)
# ✓ [48/369] BraTS20_Training_048: 15 patches (2.5s)
# ✓ [49/369] BraTS20_Training_049: 16 patches (2.5s)
# ✓ [50/369] BraTS20_Training_050: 18 patches (2.5s)
# 💾 Checkpoint saved: 50 patients processed
#
# ======================================================================
# Progress: 51/369 (13.8%)
# Elapsed: 0.04h | Remaining: ~0.23h
# Current: BraTS20_Training_051
# ======================================================================
# ✓ [51/369] BraTS20_Training_051: 19 patches (2.6s)
# ✓ [52/369] BraTS20_Training_052: 15 patches (2.6s)
# ✓ [53/369] BraTS20_Training_053: 19 patches (2.3s)
# ✓ [54/369] BraTS20_Training_054: 18 patches (1.8s)
# ✓ [55/369] BraTS20_Training_055: 18 patches (2.2s)
# ✓ [56/369] BraTS20_Training_056: 20 patches (2.0s)
# ✓ [57/369] BraTS20_Training_057: 21 patches (2.3s)
# ✓ [58/369] BraTS20_Training_058: 19 patches (2.2s)
# ✓ [59/369] BraTS20_Training_059: 19 patches (2.2s)
# ✓ [60/369] BraTS20_Training_060: 19 patches (2.2s)
#
# ======================================================================
# Progress: 61/369 (16.5%)
# Elapsed: 0.04h | Remaining: ~0.22h
# Current: BraTS20_Training_061
# ======================================================================
# ✓ [61/369] BraTS20_Training_061: 21 patches (2.2s)
# ✓ [62/369] BraTS20_Training_062: 24 patches (2.2s)
# ✓ [63/369] BraTS20_Training_063: 11 patches (2.1s)
# ✓ [64/369] BraTS20_Training_064: 19 patches (2.0s)
# ✓ [65/369] BraTS20_Training_065: 17 patches (2.0s)
# ✓ [66/369] BraTS20_Training_066: 19 patches (2.0s)
# ✓ [67/369] BraTS20_Training_067: 22 patches (2.1s)
# ✓ [68/369] BraTS20_Training_068: 19 patches (2.1s)
# ✓ [69/369] BraTS20_Training_069: 27 patches (2.1s)
# ✓ [70/369] BraTS20_Training_070: 19 patches (2.1s)
#
# ======================================================================
# Progress: 71/369 (19.2%)
# Elapsed: 0.05h | Remaining: ~0.20h
# Current: BraTS20_Training_071
# ======================================================================
# ✓ [71/369] BraTS20_Training_071: 24 patches (2.2s)
# ✓ [72/369] BraTS20_Training_072: 15 patches (2.1s)
# ✓ [73/369] BraTS20_Training_073: 17 patches (2.1s)
# ✓ [74/369] BraTS20_Training_074: 20 patches (2.1s)
# ✓ [75/369] BraTS20_Training_075: 26 patches (2.4s)
# ✓ [76/369] BraTS20_Training_076: 15 patches (2.2s)
# ✓ [77/369] BraTS20_Training_077: 19 patches (2.1s)
# ✓ [78/369] BraTS20_Training_078: 18 patches (1.8s)
# ✓ [79/369] BraTS20_Training_079: 15 patches (1.7s)
# ✓ [80/369] BraTS20_Training_080: 15 patches (1.8s)
#
# ======================================================================
# Progress: 81/369 (22.0%)
# Elapsed: 0.05h | Remaining: ~0.19h
# Current: BraTS20_Training_081
# ======================================================================
# ✓ [81/369] BraTS20_Training_081: 16 patches (1.9s)
# ✓ [82/369] BraTS20_Training_082: 19 patches (1.9s)
# ✓ [83/369] BraTS20_Training_083: 18 patches (1.9s)
# ✓ [84/369] BraTS20_Training_084: 15 patches (1.8s)
# ✓ [85/369] BraTS20_Training_085: 16 patches (1.8s)
# ✓ [86/369] BraTS20_Training_086: 10 patches (1.8s)
# ✓ [87/369] BraTS20_Training_087: 12 patches (1.8s)
# ✓ [88/369] BraTS20_Training_088: 19 patches (1.8s)
# ✓ [89/369] BraTS20_Training_089: 26 patches (1.8s)
# ✓ [90/369] BraTS20_Training_090: 19 patches (1.8s)
#
# ======================================================================
# Progress: 91/369 (24.7%)
# Elapsed: 0.06h | Remaining: ~0.18h
# Current: BraTS20_Training_091
# ======================================================================
# ✓ [91/369] BraTS20_Training_091: 26 patches (1.8s)
# ✓ [92/369] BraTS20_Training_092: 24 patches (1.8s)
# ✓ [93/369] BraTS20_Training_093: 19 patches (2.4s)
# ✓ [94/369] BraTS20_Training_094: 11 patches (2.0s)
# ✓ [95/369] BraTS20_Training_095: 24 patches (1.9s)
# ✓ [96/369] BraTS20_Training_096: 24 patches (2.5s)
# ✓ [97/369] BraTS20_Training_097: 19 patches (2.3s)
# ✓ [98/369] BraTS20_Training_098: 23 patches (2.3s)
# ✓ [99/369] BraTS20_Training_099: 15 patches (2.4s)
# ✓ [100/369] BraTS20_Training_100: 19 patches (2.4s)
# 💾 Checkpoint saved: 100 patients processed
#
# ======================================================================
# Progress: 101/369 (27.4%)
# Elapsed: 0.08h | Remaining: ~0.20h
# Current: BraTS20_Training_101
# ======================================================================
# ✓ [101/369] BraTS20_Training_101: 19 patches (2.0s)
# ✓ [102/369] BraTS20_Training_102: 15 patches (2.0s)
# ✓ [103/369] BraTS20_Training_103: 12 patches (1.9s)
# ✓ [104/369] BraTS20_Training_104: 24 patches (1.8s)
# ✓ [105/369] BraTS20_Training_105: 21 patches (1.8s)
# ✓ [106/369] BraTS20_Training_106: 23 patches (1.8s)
# ✓ [107/369] BraTS20_Training_107: 21 patches (1.7s)
# ✓ [108/369] BraTS20_Training_108: 11 patches (1.8s)
# ✓ [109/369] BraTS20_Training_109: 23 patches (1.8s)
# ✓ [110/369] BraTS20_Training_110: 18 patches (1.8s)
#
# ======================================================================
# Progress: 111/369 (30.1%)
# Elapsed: 0.08h | Remaining: ~0.19h
# Current: BraTS20_Training_111
# ======================================================================
# ✓ [111/369] BraTS20_Training_111: 18 patches (1.8s)
# ✓ [112/369] BraTS20_Training_112: 19 patches (1.9s)
# ✓ [113/369] BraTS20_Training_113: 19 patches (1.7s)
# ✓ [114/369] BraTS20_Training_114: 27 patches (1.8s)
# ✓ [115/369] BraTS20_Training_115: 18 patches (1.9s)
# ✓ [116/369] BraTS20_Training_116: 19 patches (1.7s)
# ✓ [117/369] BraTS20_Training_117: 26 patches (1.8s)
# ✓ [118/369] BraTS20_Training_118: 19 patches (1.8s)
# ✓ [119/369] BraTS20_Training_119: 15 patches (1.8s)
# ✓ [120/369] BraTS20_Training_120: 27 patches (1.8s)
#
# ======================================================================
# Progress: 121/369 (32.8%)
# Elapsed: 0.09h | Remaining: ~0.18h
# Current: BraTS20_Training_121
# ======================================================================
# ✓ [121/369] BraTS20_Training_121: 24 patches (1.8s)
# ✓ [122/369] BraTS20_Training_122: 13 patches (1.6s)
# ✓ [123/369] BraTS20_Training_123: 23 patches (1.8s)
# ✓ [124/369] BraTS20_Training_124: 27 patches (1.7s)
# ✓ [125/369] BraTS20_Training_125: 23 patches (1.8s)
# ✓ [126/369] BraTS20_Training_126: 19 patches (1.8s)
# ✓ [127/369] BraTS20_Training_127: 15 patches (1.8s)
# ✓ [128/369] BraTS20_Training_128: 15 patches (1.8s)
# ✓ [129/369] BraTS20_Training_129: 13 patches (1.8s)
# ✓ [130/369] BraTS20_Training_130: 19 patches (1.8s)
#
# ======================================================================
# Progress: 131/369 (35.5%)
# Elapsed: 0.09h | Remaining: ~0.17h
# Current: BraTS20_Training_131
# ======================================================================
# ✓ [131/369] BraTS20_Training_131: 16 patches (1.8s)
# ✓ [132/369] BraTS20_Training_132: 21 patches (1.8s)
# ✓ [133/369] BraTS20_Training_133: 19 patches (1.7s)
# ✓ [134/369] BraTS20_Training_134: 15 patches (1.8s)
# ✓ [135/369] BraTS20_Training_135: 27 patches (1.9s)
# ✓ [136/369] BraTS20_Training_136: 23 patches (1.8s)
# ✓ [137/369] BraTS20_Training_137: 23 patches (1.8s)
# ✓ [138/369] BraTS20_Training_138: 27 patches (1.8s)
# ✓ [139/369] BraTS20_Training_139: 13 patches (1.8s)
# ✓ [140/369] BraTS20_Training_140: 24 patches (1.8s)
#
# ======================================================================
# Progress: 141/369 (38.2%)
# Elapsed: 0.10h | Remaining: ~0.16h
# Current: BraTS20_Training_141
# ======================================================================
# ✓ [141/369] BraTS20_Training_141: 15 patches (1.8s)
# ✓ [142/369] BraTS20_Training_142: 11 patches (1.8s)
# ✓ [143/369] BraTS20_Training_143: 24 patches (1.8s)
# ✓ [144/369] BraTS20_Training_144: 24 patches (1.8s)
# ✓ [145/369] BraTS20_Training_145: 19 patches (1.8s)
# ✓ [146/369] BraTS20_Training_146: 19 patches (1.8s)
# ✓ [147/369] BraTS20_Training_147: 27 patches (1.8s)
# ✓ [148/369] BraTS20_Training_148: 21 patches (1.7s)
# ✓ [149/369] BraTS20_Training_149: 27 patches (1.8s)
# ✓ [150/369] BraTS20_Training_150: 27 patches (1.8s)
# 💾 Checkpoint saved: 150 patients processed
#
# ======================================================================
# Progress: 151/369 (40.9%)
# Elapsed: 0.12h | Remaining: ~0.17h
# Current: BraTS20_Training_151
# ======================================================================
# ✓ [151/369] BraTS20_Training_151: 24 patches (2.0s)
# ✓ [152/369] BraTS20_Training_152: 27 patches (1.9s)
# ✓ [153/369] BraTS20_Training_153: 18 patches (1.9s)
# ✓ [154/369] BraTS20_Training_154: 15 patches (1.8s)
# ✓ [155/369] BraTS20_Training_155: 19 patches (1.8s)
# ✓ [156/369] BraTS20_Training_156: 19 patches (1.8s)
# ✓ [157/369] BraTS20_Training_157: 21 patches (1.8s)
# ✓ [158/369] BraTS20_Training_158: 15 patches (1.7s)
# ✓ [159/369] BraTS20_Training_159: 19 patches (1.8s)
# ✓ [160/369] BraTS20_Training_160: 27 patches (1.8s)
#
# ======================================================================
# Progress: 161/369 (43.6%)
# Elapsed: 0.12h | Remaining: ~0.16h
# Current: BraTS20_Training_161
# ======================================================================
# ✓ [161/369] BraTS20_Training_161: 23 patches (1.8s)
# ✓ [162/369] BraTS20_Training_162: 24 patches (1.8s)
# ✓ [163/369] BraTS20_Training_163: 23 patches (1.8s)
# ✓ [164/369] BraTS20_Training_164: 21 patches (1.8s)
# ✓ [165/369] BraTS20_Training_165: 21 patches (1.8s)
# ✓ [166/369] BraTS20_Training_166: 26 patches (1.8s)
# ✓ [167/369] BraTS20_Training_167: 24 patches (1.8s)
# ✓ [168/369] BraTS20_Training_168: 19 patches (1.7s)
# ✓ [169/369] BraTS20_Training_169: 15 patches (1.8s)
# ✓ [170/369] BraTS20_Training_170: 18 patches (1.8s)
#
# ======================================================================
# Progress: 171/369 (46.3%)
# Elapsed: 0.13h | Remaining: ~0.15h
# Current: BraTS20_Training_171
# ======================================================================
# ✓ [171/369] BraTS20_Training_171: 27 patches (1.8s)
# ✓ [172/369] BraTS20_Training_172: 18 patches (1.9s)
# ✓ [173/369] BraTS20_Training_173: 19 patches (1.8s)
# ✓ [174/369] BraTS20_Training_174: 19 patches (1.7s)
# ✓ [175/369] BraTS20_Training_175: 27 patches (1.8s)
# ✓ [176/369] BraTS20_Training_176: 19 patches (1.8s)
# ✓ [177/369] BraTS20_Training_177: 11 patches (1.8s)
# ✓ [178/369] BraTS20_Training_178: 15 patches (1.8s)
# ✓ [179/369] BraTS20_Training_179: 18 patches (1.9s)
# ✓ [180/369] BraTS20_Training_180: 23 patches (3.0s)
#
# ======================================================================
# Progress: 181/369 (49.1%)
# Elapsed: 0.13h | Remaining: ~0.14h
# Current: BraTS20_Training_181
# ======================================================================
# ✓ [181/369] BraTS20_Training_181: 15 patches (1.8s)
# ✓ [182/369] BraTS20_Training_182: 19 patches (1.8s)
# ✓ [183/369] BraTS20_Training_183: 24 patches (1.7s)
# ✓ [184/369] BraTS20_Training_184: 23 patches (1.8s)
# ✓ [185/369] BraTS20_Training_185: 23 patches (1.8s)
# ✓ [186/369] BraTS20_Training_186: 19 patches (1.8s)
# ✓ [187/369] BraTS20_Training_187: 24 patches (1.8s)
# ✓ [188/369] BraTS20_Training_188: 24 patches (1.8s)
# ✓ [189/369] BraTS20_Training_189: 18 patches (1.8s)
# ✓ [190/369] BraTS20_Training_190: 19 patches (1.8s)
#
# ======================================================================
# Progress: 191/369 (51.8%)
# Elapsed: 0.14h | Remaining: ~0.13h
# Current: BraTS20_Training_191
# ======================================================================
# ✓ [191/369] BraTS20_Training_191: 26 patches (1.9s)
# ✓ [192/369] BraTS20_Training_192: 16 patches (1.8s)
# ✓ [193/369] BraTS20_Training_193: 23 patches (1.9s)
# ✓ [194/369] BraTS20_Training_194: 19 patches (1.8s)
# ✓ [195/369] BraTS20_Training_195: 15 patches (1.8s)
# ✓ [196/369] BraTS20_Training_196: 26 patches (1.8s)
# ✓ [197/369] BraTS20_Training_197: 24 patches (1.8s)
# ✓ [198/369] BraTS20_Training_198: 19 patches (1.8s)
# ✓ [199/369] BraTS20_Training_199: 15 patches (1.8s)
# ✓ [200/369] BraTS20_Training_200: 18 patches (1.8s)
# 💾 Checkpoint saved: 200 patients processed
#
# ======================================================================
# Progress: 201/369 (54.5%)
# Elapsed: 0.16h | Remaining: ~0.14h
# Current: BraTS20_Training_201
# ======================================================================
# ✓ [201/369] BraTS20_Training_201: 23 patches (1.9s)
# ✓ [202/369] BraTS20_Training_202: 15 patches (1.9s)
# ✓ [203/369] BraTS20_Training_203: 19 patches (1.8s)
# ✓ [204/369] BraTS20_Training_204: 10 patches (1.8s)
# ✓ [205/369] BraTS20_Training_205: 14 patches (1.8s)
# ✓ [206/369] BraTS20_Training_206: 19 patches (1.8s)
# ✓ [207/369] BraTS20_Training_207: 20 patches (1.8s)
# ✓ [208/369] BraTS20_Training_208: 24 patches (1.8s)
# ✓ [209/369] BraTS20_Training_209: 16 patches (1.8s)
# ✓ [210/369] BraTS20_Training_210: 27 patches (1.7s)
#
# ======================================================================
# Progress: 211/369 (57.2%)
# Elapsed: 0.17h | Remaining: ~0.13h
# Current: BraTS20_Training_211
# ======================================================================
# ✓ [211/369] BraTS20_Training_211: 21 patches (1.8s)
# ✓ [212/369] BraTS20_Training_212: 27 patches (1.8s)
# ✓ [213/369] BraTS20_Training_213: 18 patches (1.8s)
# ✓ [214/369] BraTS20_Training_214: 19 patches (1.8s)
# ✓ [215/369] BraTS20_Training_215: 18 patches (1.8s)
# ✓ [216/369] BraTS20_Training_216: 19 patches (1.8s)
# ✓ [217/369] BraTS20_Training_217: 8 patches (1.8s)
# ✓ [218/369] BraTS20_Training_218: 23 patches (1.7s)
# ✓ [219/369] BraTS20_Training_219: 19 patches (1.7s)
# ✓ [220/369] BraTS20_Training_220: 19 patches (1.8s)
#
# ======================================================================
# Progress: 221/369 (59.9%)
# Elapsed: 0.17h | Remaining: ~0.12h
# Current: BraTS20_Training_221
# ======================================================================
# ✓ [221/369] BraTS20_Training_221: 23 patches (1.8s)
# ✓ [222/369] BraTS20_Training_222: 13 patches (1.8s)
# ✓ [223/369] BraTS20_Training_223: 23 patches (1.8s)
# ✓ [224/369] BraTS20_Training_224: 19 patches (1.8s)
# ✓ [225/369] BraTS20_Training_225: 26 patches (1.8s)
# ✓ [226/369] BraTS20_Training_226: 19 patches (1.8s)
# ✓ [227/369] BraTS20_Training_227: 26 patches (1.8s)
# ✓ [228/369] BraTS20_Training_228: 19 patches (1.8s)
# ✓ [229/369] BraTS20_Training_229: 19 patches (1.8s)
# ✓ [230/369] BraTS20_Training_230: 19 patches (1.8s)
#
# ======================================================================
# Progress: 231/369 (62.6%)
# Elapsed: 0.18h | Remaining: ~0.11h
# Current: BraTS20_Training_231
# ======================================================================
# ✓ [231/369] BraTS20_Training_231: 18 patches (1.9s)
# ✓ [232/369] BraTS20_Training_232: 15 patches (1.8s)
# ✓ [233/369] BraTS20_Training_233: 9 patches (1.8s)
# ✓ [234/369] BraTS20_Training_234: 26 patches (1.8s)
# ✓ [235/369] BraTS20_Training_235: 27 patches (1.8s)
# ✓ [236/369] BraTS20_Training_236: 19 patches (1.8s)
# ✓ [237/369] BraTS20_Training_237: 26 patches (1.8s)
# ✓ [238/369] BraTS20_Training_238: 23 patches (1.8s)
# ✓ [239/369] BraTS20_Training_239: 23 patches (1.9s)
# ✓ [240/369] BraTS20_Training_240: 23 patches (1.8s)
#
# ======================================================================
# Progress: 241/369 (65.3%)
# Elapsed: 0.18h | Remaining: ~0.10h
# Current: BraTS20_Training_241
# ======================================================================
# ✓ [241/369] BraTS20_Training_241: 24 patches (1.8s)
# ✓ [242/369] BraTS20_Training_242: 15 patches (1.9s)
# ✓ [243/369] BraTS20_Training_243: 26 patches (1.8s)
# ✓ [244/369] BraTS20_Training_244: 19 patches (1.9s)
# ✓ [245/369] BraTS20_Training_245: 23 patches (1.8s)
# ✓ [246/369] BraTS20_Training_246: 18 patches (1.8s)
# ✓ [247/369] BraTS20_Training_247: 19 patches (1.9s)
# ✓ [248/369] BraTS20_Training_248: 19 patches (1.8s)
# ✓ [249/369] BraTS20_Training_249: 15 patches (1.9s)
# ✓ [250/369] BraTS20_Training_250: 19 patches (1.8s)
# 💾 Checkpoint saved: 250 patients processed
#
# ======================================================================
# Progress: 251/369 (68.0%)
# Elapsed: 0.22h | Remaining: ~0.10h
# Current: BraTS20_Training_251
# ======================================================================
# ✓ [251/369] BraTS20_Training_251: 19 patches (1.9s)
# ✓ [252/369] BraTS20_Training_252: 24 patches (1.9s)
# ✓ [253/369] BraTS20_Training_253: 15 patches (1.9s)
# ✓ [254/369] BraTS20_Training_254: 21 patches (1.8s)
# ✓ [255/369] BraTS20_Training_255: 19 patches (1.8s)
# ✓ [256/369] BraTS20_Training_256: 19 patches (1.8s)
# ✓ [257/369] BraTS20_Training_257: 16 patches (1.8s)
# ✓ [258/369] BraTS20_Training_258: 19 patches (1.7s)
# ✓ [259/369] BraTS20_Training_259: 21 patches (1.8s)
# ✓ [260/369] BraTS20_Training_260: 23 patches (1.8s)
#
# ======================================================================
# Progress: 261/369 (70.7%)
# Elapsed: 0.22h | Remaining: ~0.09h
# Current: BraTS20_Training_261
# ======================================================================
# ✓ [261/369] BraTS20_Training_261: 27 patches (1.8s)
# ✓ [262/369] BraTS20_Training_262: 19 patches (1.8s)
# ✓ [263/369] BraTS20_Training_263: 15 patches (1.8s)
# ✓ [264/369] BraTS20_Training_264: 15 patches (1.8s)
# ✓ [265/369] BraTS20_Training_265: 19 patches (1.8s)
# ✓ [266/369] BraTS20_Training_266: 16 patches (1.8s)
# ✓ [267/369] BraTS20_Training_267: 19 patches (1.8s)
# ✓ [268/369] BraTS20_Training_268: 13 patches (1.8s)
# ✓ [269/369] BraTS20_Training_269: 13 patches (1.8s)
# ✓ [270/369] BraTS20_Training_270: 23 patches (1.8s)
#
# ======================================================================
# Progress: 271/369 (73.4%)
# Elapsed: 0.23h | Remaining: ~0.08h
# Current: BraTS20_Training_271
# ======================================================================
# ✓ [271/369] BraTS20_Training_271: 19 patches (1.7s)
# ✓ [272/369] BraTS20_Training_272: 24 patches (1.7s)
# ✓ [273/369] BraTS20_Training_273: 27 patches (1.9s)
# ✓ [274/369] BraTS20_Training_274: 27 patches (1.8s)
# ✓ [275/369] BraTS20_Training_275: 15 patches (1.9s)
# ✓ [276/369] BraTS20_Training_276: 18 patches (1.7s)
# ✓ [277/369] BraTS20_Training_277: 11 patches (1.8s)
# ✓ [278/369] BraTS20_Training_278: 15 patches (1.8s)
# ✓ [279/369] BraTS20_Training_279: 15 patches (1.8s)
# ✓ [280/369] BraTS20_Training_280: 19 patches (1.8s)
#
# ======================================================================
# Progress: 281/369 (76.2%)
# Elapsed: 0.23h | Remaining: ~0.07h
# Current: BraTS20_Training_281
# ======================================================================
# ✓ [281/369] BraTS20_Training_281: 23 patches (1.8s)
# ✓ [282/369] BraTS20_Training_282: 23 patches (1.8s)
# ✓ [283/369] BraTS20_Training_283: 15 patches (1.8s)
# ✓ [284/369] BraTS20_Training_284: 26 patches (1.8s)
# ✓ [285/369] BraTS20_Training_285: 24 patches (1.8s)
# ✓ [286/369] BraTS20_Training_286: 13 patches (1.8s)
# ✓ [287/369] BraTS20_Training_287: 11 patches (1.8s)
# ✓ [288/369] BraTS20_Training_288: 15 patches (1.8s)
# ✓ [289/369] BraTS20_Training_289: 27 patches (1.8s)
# ✓ [290/369] BraTS20_Training_290: 27 patches (1.8s)
#
# ======================================================================
# Progress: 291/369 (78.9%)
# Elapsed: 0.24h | Remaining: ~0.06h
# Current: BraTS20_Training_291
# ======================================================================
# ✓ [291/369] BraTS20_Training_291: 27 patches (1.9s)
# ✓ [292/369] BraTS20_Training_292: 18 patches (1.8s)
# ✓ [293/369] BraTS20_Training_293: 27 patches (1.8s)
# ✓ [294/369] BraTS20_Training_294: 19 patches (1.9s)
# ✓ [295/369] BraTS20_Training_295: 15 patches (1.8s)
# ✓ [296/369] BraTS20_Training_296: 23 patches (1.8s)
# ✓ [297/369] BraTS20_Training_297: 16 patches (1.8s)
# ✓ [298/369] BraTS20_Training_298: 19 patches (1.8s)
# ✓ [299/369] BraTS20_Training_299: 19 patches (1.8s)
# ✓ [300/369] BraTS20_Training_300: 21 patches (1.9s)
# ❌ [300/369] BraTS20_Training_300: Error -
#
# ======================================================================
# Progress: 301/369 (81.6%)
# Elapsed: 0.28h | Remaining: ~0.06h
# Current: BraTS20_Training_301
# ======================================================================
# ✓ [301/369] BraTS20_Training_301: 26 patches (1.9s)
# ✓ [302/369] BraTS20_Training_302: 19 patches (1.9s)
# ✓ [303/369] BraTS20_Training_303: 16 patches (1.9s)
# ✓ [304/369] BraTS20_Training_304: 15 patches (1.9s)
# ✓ [305/369] BraTS20_Training_305: 24 patches (1.8s)
# ✓ [306/369] BraTS20_Training_306: 27 patches (1.7s)
# ✓ [307/369] BraTS20_Training_307: 26 patches (1.8s)
# ✓ [308/369] BraTS20_Training_308: 24 patches (1.8s)
# ✓ [309/369] BraTS20_Training_309: 27 patches (1.8s)
# ✓ [310/369] BraTS20_Training_310: 27 patches (1.8s)
#
# ======================================================================
# Progress: 311/369 (84.3%)
# Elapsed: 0.28h | Remaining: ~0.05h
# Current: BraTS20_Training_311
# ======================================================================
# ✓ [311/369] BraTS20_Training_311: 15 patches (1.8s)
# ✓ [312/369] BraTS20_Training_312: 27 patches (1.7s)
# ✓ [313/369] BraTS20_Training_313: 27 patches (1.7s)
# ✓ [314/369] BraTS20_Training_314: 10 patches (1.8s)
# ✓ [315/369] BraTS20_Training_315: 15 patches (1.8s)
# ✓ [316/369] BraTS20_Training_316: 26 patches (1.7s)
# ✓ [317/369] BraTS20_Training_317: 10 patches (1.8s)
# ✓ [318/369] BraTS20_Training_318: 27 patches (1.8s)
# ✓ [319/369] BraTS20_Training_319: 19 patches (1.7s)
# ✓ [320/369] BraTS20_Training_320: 18 patches (1.8s)
#
# ======================================================================
# Progress: 321/369 (87.0%)
# Elapsed: 0.29h | Remaining: ~0.04h
# Current: BraTS20_Training_321
# ======================================================================
# ✓ [321/369] BraTS20_Training_321: 19 patches (1.8s)
# ✓ [322/369] BraTS20_Training_322: 19 patches (1.8s)
# ✓ [323/369] BraTS20_Training_323: 24 patches (1.8s)
# ✓ [324/369] BraTS20_Training_324: 19 patches (1.9s)
# ✓ [325/369] BraTS20_Training_325: 12 patches (1.7s)
# ✓ [326/369] BraTS20_Training_326: 19 patches (1.8s)
# ✓ [327/369] BraTS20_Training_327: 24 patches (1.8s)
# ✓ [328/369] BraTS20_Training_328: 27 patches (1.9s)
# ✓ [329/369] BraTS20_Training_329: 18 patches (1.9s)
# ✓ [330/369] BraTS20_Training_330: 19 patches (1.8s)
#
# ======================================================================
# Progress: 331/369 (89.7%)
# Elapsed: 0.29h | Remaining: ~0.03h
# Current: BraTS20_Training_331
# ======================================================================
# ✓ [331/369] BraTS20_Training_331: 15 patches (1.8s)
# ✓ [332/369] BraTS20_Training_332: 15 patches (1.8s)
# ✓ [333/369] BraTS20_Training_333: 23 patches (1.8s)
# ✓ [334/369] BraTS20_Training_334: 19 patches (1.8s)
# ✓ [335/369] BraTS20_Training_335: 27 patches (1.7s)
# ✓ [336/369] BraTS20_Training_336: 16 patches (1.8s)
# ✓ [337/369] BraTS20_Training_337: 18 patches (1.9s)
# ✓ [338/369] BraTS20_Training_338: 27 patches (1.8s)
# ✓ [339/369] BraTS20_Training_339: 23 patches (1.8s)
# ✓ [340/369] BraTS20_Training_340: 27 patches (1.9s)
#
# ======================================================================
# Progress: 341/369 (92.4%)
# Elapsed: 0.30h | Remaining: ~0.02h
# Current: BraTS20_Training_341
# ======================================================================
# ✓ [341/369] BraTS20_Training_341: 10 patches (1.9s)
# ✓ [342/369] BraTS20_Training_342: 24 patches (1.9s)
# ✓ [343/369] BraTS20_Training_343: 19 patches (1.9s)
# ✓ [344/369] BraTS20_Training_344: 19 patches (1.8s)
# ✓ [345/369] BraTS20_Training_345: 19 patches (1.9s)
# ✓ [346/369] BraTS20_Training_346: 21 patches (2.0s)
# ✓ [347/369] BraTS20_Training_347: 23 patches (2.0s)
# ✓ [348/369] BraTS20_Training_348: 21 patches (2.0s)
# ✓ [349/369] BraTS20_Training_349: 24 patches (1.9s)
# ✓ [350/369] BraTS20_Training_350: 15 patches (2.1s)
# ❌ [350/369] BraTS20_Training_350: Error -
#
# ======================================================================
# Progress: 351/369 (95.1%)
# Elapsed: 0.34h | Remaining: ~0.02h
# Current: BraTS20_Training_351
# ======================================================================
# ✓ [351/369] BraTS20_Training_351: 19 patches (2.1s)
# ✓ [352/369] BraTS20_Training_352: 13 patches (2.0s)
# ✓ [353/369] BraTS20_Training_353: 13 patches (2.0s)
# ✓ [354/369] BraTS20_Training_354: 27 patches (2.0s)
# ⚠️  [355/369] BraTS20_Training_355: Missing modalities
# ✓ [356/369] BraTS20_Training_356: 10 patches (1.8s)
# ✓ [357/369] BraTS20_Training_357: 19 patches (1.8s)
# ✓ [358/369] BraTS20_Training_358: 19 patches (1.8s)
# ✓ [359/369] BraTS20_Training_359: 15 patches (1.8s)
# ✓ [360/369] BraTS20_Training_360: 18 patches (1.8s)
#
# ======================================================================
# Progress: 361/369 (97.8%)
# Elapsed: 0.34h | Remaining: ~0.01h
# Current: BraTS20_Training_361
# ======================================================================
# ✓ [361/369] BraTS20_Training_361: 16 patches (1.9s)
# ✓ [362/369] BraTS20_Training_362: 19 patches (1.9s)
# ✓ [363/369] BraTS20_Training_363: 19 patches (1.9s)
# ✓ [364/369] BraTS20_Training_364: 19 patches (1.8s)
# ✓ [365/369] BraTS20_Training_365: 24 patches (1.9s)
# ✓ [366/369] BraTS20_Training_366: 13 patches (2.0s)
# ✓ [367/369] BraTS20_Training_367: 19 patches (1.9s)
# ✓ [368/369] BraTS20_Training_368: 18 patches (1.9s)
#
# ======================================================================
# Progress: 369/369 (100.0%)
# Elapsed: 0.35h | Remaining: ~0.00h
# Current: BraTS20_Training_369
# ======================================================================
# ✓ [369/369] BraTS20_Training_369: 25 patches (1.8s)
#
# ======================================================================
# PROCESSING COMPLETE!
# ======================================================================
# Total time: 0.35 hours
# Successfully processed: 368/369 patients
# Failed: 3 patients
#
# Total patches: 7235
# Tumor patches: 6731 (93.0%)
# Background patches: 504 (7.0%)
# Average patches per patient: 19
# ======================================================================
#
# ⚠️  Failed patients (3):
#   • BraTS20_Training_300:
#   • BraTS20_Training_350:
#   • BraTS20_Training_355: Missing modalities

# %%
# Cell 8: Train-Validation Split

def stratified_split_patches(patches, val_ratio=0.2):
    tumor_patches = [p for p in patches if p['tumor_ratio'] >= TUMOR_THRESHOLD]
    background_patches = [p for p in patches if p['tumor_ratio'] < TUMOR_THRESHOLD]
    
    n_tumor_val = int(len(tumor_patches) * val_ratio)
    tumor_val = tumor_patches[:n_tumor_val]
    tumor_train = tumor_patches[n_tumor_val:]
    
    n_bg_val = int(len(background_patches) * val_ratio)
    bg_val = background_patches[:n_bg_val]
    bg_train = background_patches[n_bg_val:]
    
    train_patches = tumor_train + bg_train
    val_patches = tumor_val + bg_val
    
    np.random.shuffle(train_patches)
    np.random.shuffle(val_patches)
    
    return train_patches, val_patches

if len(all_patches) > 0:
    train_patches, val_patches = stratified_split_patches(all_patches, TRAIN_VAL_SPLIT)

    print("="*70)
    print("TRAIN-VALIDATION SPLIT")
    print("="*70)
    print(f"Training patches: {len(train_patches)} ({100*len(train_patches)/(len(train_patches)+len(val_patches)):.1f}%)")
    print(f"  Tumor: {sum(1 for p in train_patches if p['tumor_ratio'] >= TUMOR_THRESHOLD)}")
    print(f"  Background: {sum(1 for p in train_patches if p['tumor_ratio'] < TUMOR_THRESHOLD)}")

    print(f"\nValidation patches: {len(val_patches)} ({100*len(val_patches)/(len(train_patches)+len(val_patches)):.1f}%)")
    print(f"  Tumor: {sum(1 for p in val_patches if p['tumor_ratio'] >= TUMOR_THRESHOLD)}")
    print(f"  Background: {sum(1 for p in val_patches if p['tumor_ratio'] < TUMOR_THRESHOLD)}")
    print("="*70)
# Out:
# ======================================================================
# TRAIN-VALIDATION SPLIT
# ======================================================================
# Training patches: 5789 (80.0%)
#   Tumor: 5385
#   Background: 404
#
# Validation patches: 1446 (20.0%)
#   Tumor: 1346
#   Background: 100
# ======================================================================

# %%
# Cell 9: Save Preprocessed Patches (FIXED - Memory Optimized)

def save_patches(patches, split_name, output_dir):
    """
    Save patches as .npy files with memory optimization.
    Includes error handling and memory cleanup.
    """
    image_dir = os.path.join(output_dir, split_name, 'images')
    mask_dir = os.path.join(output_dir, split_name, 'masks')
    
    print(f"\nSaving {split_name} patches...")
    
    saved_count = 0
    failed_count = 0
    
    for idx, patch in enumerate(tqdm(patches, desc=f"Saving {split_name}")):
        try:
            # Save image
            image_path = os.path.join(image_dir, f"patch_{idx:05d}.npy")
            image_data = patch['image'].copy()  # Make explicit copy
            np.save(image_path, image_data, allow_pickle=False)
            del image_data  # Free memory immediately
            
            # Save mask
            mask_path = os.path.join(mask_dir, f"patch_{idx:05d}.npy")
            mask_data = patch['mask'].copy()  # Make explicit copy
            np.save(mask_path, mask_data, allow_pickle=False)
            del mask_data  # Free memory immediately
            
            saved_count += 1
            
            # Periodic garbage collection for large datasets
            if (idx + 1) % 100 == 0:
                import gc
                gc.collect()
            
        except Exception as e:
            print(f"\n⚠️  Error saving patch {idx}: {str(e)}")
            failed_count += 1
            
            # Try alternative save method (compressed)
            try:
                print(f"   Attempting compressed save...")
                np.savez_compressed(image_path.replace('.npy', '.npz'), 
                                   data=patch['image'])
                np.savez_compressed(mask_path.replace('.npy', '.npz'), 
                                   data=patch['mask'])
                saved_count += 1
                failed_count -= 1
                print(f"   ✓ Compressed save successful")
            except Exception as e2:
                print(f"   ❌ Compressed save also failed: {str(e2)}")
    
    print(f"\n✓ Saved {saved_count}/{len(patches)} {split_name} patches")
    if failed_count > 0:
        print(f"⚠️  Failed to save {failed_count} patches")
    print(f"  Images: {image_dir}")
    print(f"  Masks: {mask_dir}")

if len(all_patches) > 0:
    # Save train patches
    save_patches(train_patches, 'train', OUTPUT_DIR)
    
    # Clean up memory between saves
    import gc
    gc.collect()
    
    # Save validation patches
    save_patches(val_patches, 'val', OUTPUT_DIR)
    
    print("\n" + "="*70)
    print("✓ ALL PATCHES SAVED SUCCESSFULLY")
    print("="*70)
else:
    print("\n❌ No patches to save!")
# Out:
# Saving train patches...
# Saving train: 100%|██████████| 5789/5789 [05:52<00:00, 16.41it/s]
# ✓ Saved 5789/5789 train patches
#   Images: ..\processed_data\train\images
#   Masks: ..\processed_data\train\masks
#
# Saving val patches...
# Saving val: 100%|██████████| 1446/1446 [01:22<00:00, 17.45it/s]
# ✓ Saved 1446/1446 val patches
#   Images: ..\processed_data\val\images
#   Masks: ..\processed_data\val\masks
#
# ======================================================================
# ✓ ALL PATCHES SAVED SUCCESSFULLY
# ======================================================================

# %%
# Cell 10: Save Metadata

if len(all_patches) > 0:
    metadata = {
        'num_patients_attempted': len(PATIENT_IDS),
        'num_patients_processed': len(processed_patients),
        'num_patients_failed': len(failed_patients),
        'patient_ids': processed_patients,
        'failed_patients': failed_patients,
        'target_shape': TARGET_SHAPE,
        'patch_size': PATCH_SIZE,
        'stride': STRIDE,
        'train_val_split': TRAIN_VAL_SPLIT,
        'tumor_threshold': TUMOR_THRESHOLD,
        'background_sample_ratio': BACKGROUND_SAMPLE_RATIO,
        'n_train_patches': len(train_patches),
        'n_val_patches': len(val_patches),
        'n_tumor_patches': len(all_tumor_patches),
        'n_background_patches': len(all_background_patches),
        'tumor_patch_percentage': 100 * len(all_tumor_patches) / len(all_patches),
        'processing_time_hours': (time.time() - start_time) / 3600,
        'modalities': ['flair', 't1', 't1ce', 't2'],
        'normalization': 'z-score',
        'dataset': 'BraTS2020_Full'
    }

    metadata_path = os.path.join(OUTPUT_DIR, 'metadata', 'preprocessing_config.npy')
    np.save(metadata_path, metadata)
    print(f"✓ Metadata saved: {metadata_path}")
# Out:
# ✓ Metadata saved: ..\processed_data\metadata\preprocessing_config.npy

# %%
# Cell 11: Final Summary Report

print("\n" + "="*70)
print(" "*15 + "📊 WEEK-2 FINAL SUMMARY (FULL DATASET)")
print("="*70)

if len(all_patches) > 0:
    print(f"\n{'DATASET STATISTICS'}")
    print("-"*70)
    print(f"  Patients attempted: {len(PATIENT_IDS)}")
    print(f"  Successfully processed: {len(processed_patients)} ({100*len(processed_patients)/len(PATIENT_IDS):.1f}%)")
    print(f"  Failed: {len(failed_patients)} ({100*len(failed_patients)/len(PATIENT_IDS):.1f}%)")
    print(f"  Average patches/patient: {len(all_patches)//len(processed_patients)}")

    print(f"\n{'PATCH STATISTICS'}")
    print("-"*70)
    print(f"  Total patches: {len(all_patches):,}")
    print(f"  Training: {len(train_patches):,} ({100*len(train_patches)/(len(train_patches)+len(val_patches)):.1f}%)")
    print(f"  Validation: {len(val_patches):,} ({100*len(val_patches)/(len(train_patches)+len(val_patches)):.1f}%)")
    print(f"  Tumor patches: {len(all_tumor_patches):,} ({100*len(all_tumor_patches)/len(all_patches):.1f}%)")
    print(f"  Background patches: {len(all_background_patches):,} ({100*len(all_background_patches)/len(all_patches):.1f}%)")

    print(f"\n{'PROCESSING TIME'}")
    print("-"*70)
    total_hours = (time.time() - start_time) / 3600
    print(f"  Total time: {total_hours:.2f} hours")
    print(f"  Time per patient: {total_hours*60/len(processed_patients):.2f} minutes")

    print(f"\n{'STORAGE'}")
    print("-"*70)
    patch_size_bytes = np.prod(PATCH_SIZE) * 4 * 4
    mask_size_bytes = np.prod(PATCH_SIZE) * 4
    total_size_gb = (len(train_patches) + len(val_patches)) * (patch_size_bytes + mask_size_bytes) / (1024**3)
    print(f"  Estimated size: {total_size_gb:.2f} GB")

    print(f"\n{'DATA QUALITY ASSESSMENT'}")
    print("-"*70)
    if len(all_patches) >= 5000:
        print(f"  ✅ EXCELLENT: {len(all_patches):,} patches")
        print(f"     This is professional-grade training data!")
    elif len(all_patches) >= 3000:
        print(f"  ✅ VERY GOOD: {len(all_patches):,} patches")
        print(f"     Sufficient for high-quality training.")
    elif len(all_patches) >= 1000:
        print(f"  ✅ GOOD: {len(all_patches):,} patches")
        print(f"     Acceptable for training.")
    else:
        print(f"  ⚠️  BORDERLINE: {len(all_patches):,} patches")

    print("\n" + "="*70)
    print("✅ WEEK-2 PREPROCESSING COMPLETE (FULL DATASET)!")
    print(f"🎯 Generated {len(all_patches):,} patches from {len(processed_patients)} patients")
    print(f"💾 Data saved to: {OUTPUT_DIR}")
    print("🚀 Ready for Week-4: Training with Maximum Data!")
    print("="*70)
    print(f"\nEnd time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ======================================================================
#                📊 WEEK-2 FINAL SUMMARY (FULL DATASET)
# ======================================================================
#
# DATASET STATISTICS
# ----------------------------------------------------------------------
#   Patients attempted: 369
#   Successfully processed: 368 (99.7%)
#   Failed: 3 (0.8%)
#   Average patches/patient: 19
#
# PATCH STATISTICS
# ----------------------------------------------------------------------
#   Total patches: 7,235
#   Training: 5,789 (80.0%)
#   Validation: 1,446 (20.0%)
#   Tumor patches: 6,731 (93.0%)
#   Background patches: 504 (7.0%)
#
# PROCESSING TIME
# ----------------------------------------------------------------------
#   Total time: 0.47 hours
#   Time per patient: 0.08 minutes
#
# STORAGE
# ----------------------------------------------------------------------
#   Estimated size: 35.33 GB
#
# DATA QUALITY ASSESSMENT
# ----------------------------------------------------------------------
#   ✅ EXCELLENT: 7,235 patches
#      This is professional-grade training data!
#
# ======================================================================
# ✅ WEEK-2 PREPROCESSING COMPLETE (FULL DATASET)!
# 🎯 Generated 7,235 patches from 368 patients
# 💾 Data saved to: ..\processed_data
# 🚀 Ready for Week-4: Training with Maximum Data!
# ======================================================================
#
# End time: 2025-10-30 17:01:50
